# %%
1+1
# Out:
# 2

# %%
## テスト
### テスト

# %%
squares = [1,2,4,51,43]
print(squares)
# Out:
# [1, 2, 4, 51, 43]

# %%
contacts = {'Taro':1234,'Jiro':5678}
print(contacts)
print(contacts['Taro'])
contacts['Saburo'] = 9012
print(contacts)
# Out:
# {'Taro': 1234, 'Jiro': 5678}
# 1234
# {'Taro': 1234, 'Jiro': 5678, 'Saburo': 9012}

# %%
squares = [v** 2 for v in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
import numpy
    
a = numpy.array([0,1,2,3])
print(a)

b = numpy.array([[0,1,2,3],[0,1,2,3]])
print(b)

print("a.shape",a.shape)
print("b.shape",b.shape)

print("a.shape",a.size)
print("b.shape",b.size)
# Out:
#   File "<ipython-input-11-ec1d525c3f51>", line 15
#     ＃　はいれつ
#      　   ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# # こんにちは
# ## あ
# #### あああ

# %%
# 0から４までの整数を持つ配列をつくる
print(numpy.arange(5))
# Out:
# [0 1 2 3 4]

# %%
# 1から９までの整数のうち奇数の配列を作る
print(numpy.arange(1,10,3))

print("6", numpy.arange(6))
print("2*3",numpy.arange(6).reshape(2,3))

print(numpy.eye(2))
# Out:
# [1 4 7]
# 6 [0 1 2 3 4 5]
# 2*3 [[0 1 2]
#  [3 4 5]]
# [[1. 0.]
#  [0. 1.]]

# %%
# %matplotlib inline
from matplotlib import pyplot
pyplot.rcParams['font.family'] = 'IPAPGothic'

# %%
import numpy
x = numpy.linspace(-numpy.pi * 2, numpy.pi *2 ,1024, endpoint=True)
y_sin = numpy.sin(x)
y_cos = numpy.cos(x)


#グラフサイズの変更
pyplot.figure(figsize=(11,7))
## 判例をつけるときはLabelを最後の引数に入れる必要がある
pyplot.plot(x, y_sin, color= 'blue', linewidth=3.0, label=r'$\sins(x)$')
pyplot.plot(x, y_cos, color= 'red', linewidth=1.0, label=r'$\co(x)$')

#x軸の最小値、最大値を xの最小値、最大値の1.2倍とする
pyplot.xlim(x.min() * 1.2, x.max()*1.2)
#y軸の最小値、最大値を y_sinの最小値、最大値の1.2倍とする
pyplot.xlim(y_sin.min() * 1.2, y_sin.max()*1.2)

# x軸のメモリ設定　リストを与える
pyplot.xticks([-numpy.pi * 2, -numpy.pi,0,numpy.pi,numpy.pi*2])
# y軸のメモリ設定　リストを与える
pyplot.yticks([-1, -0.5,0, 0.5,1])


# 判例追加
pyplot.legend()
# グラフ描画
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2507         try:
# -> 2508             result = self._expression.parseString(s)
#    2509         except ParseBaseException as err:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1827                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1828                 raise exc
#    1829         else:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1817         try:
# -> 1818             loc, tokens = self._parse( instring, 0 )
#    1819             if parseAll:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4097         if self.expr is not None:
# -> 4098             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4099         else:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3751             else:
# -> 3752                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3753             if exprtokens or exprtokens.haskeys():
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4391         try:
# -> 4392             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4393         except (ParseException,IndexError):
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4321             try_not_ender(instring, loc)
# -> 4322         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    4323         try:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3734         # pre-parsed the string as part of our And pre-parsing
# -> 3735         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3736         errorStop = False
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1594                     try:
# -> 1595                         tokens = fn( instring, tokensStart, retTokens )
#    1596                     except IndexError as parse_action_exc:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in wrapper(*args)
#    1216             try:
# -> 1217                 ret = func(*args[limit[0]:])
#    1218                 foundArity[0] = True
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2575     def math_string(self, s, loc, toks):
# -> 2576         return self._math_expression.parseString(toks[0][1:-1])
#    2577
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1827                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1828                 raise exc
#    1829         else:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1817         try:
# -> 1818             loc, tokens = self._parse( instring, 0 )
#    1819             if parseAll:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4097         if self.expr is not None:
# -> 4098             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4099         else:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4321             try_not_ender(instring, loc)
# -> 4322         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    4323         try:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4097         if self.expr is not None:
# -> 4098             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4099         else:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3901             try:
# -> 3902                 ret = e._parse( instring, loc, doActions )
#    3903                 return ret
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1594                     try:
# -> 1595                         tokens = fn( instring, tokensStart, retTokens )
#    1596                     except IndexError as parse_action_exc:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/pyparsing.py in wrapper(*args)
#    1216             try:
# -> 1217                 ret = func(*args[limit[0]:])
#    1218                 foundArity[0] = True
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/mathtext.py in unknown_symbol(self, s, loc, toks)
#    2667         c = toks[0]
# -> 2668         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2669
#
# ParseFatalException: Unknown symbol: \co (at char 0), (line:1, col:1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/legend.py in draw(self, renderer)
#     634         # update the location and size of the legend. This needs to
#     635         # be done in any case to clip the figure right.
# --> 636         bbox = self._legend_box.get_window_extent(renderer)
#     637         self.legendPatch.set_bounds(bbox.x0, bbox.y0,
#     638                                     bbox.width, bbox.height)
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_window_extent(self, renderer)
#     248         get the bounding box in display space.
#     249         '''
# --> 250         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     251         px, py = self.get_offset(w, h, xd, yd, renderer)
#     252         return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent_offsets(self, renderer)
#     368
#     369         whd_list = [c.get_extent(renderer)
# --> 370                     for c in self.get_visible_children()]
#     371         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     372
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in <listcomp>(.0)
#     368
#     369         whd_list = [c.get_extent(renderer)
# --> 370                     for c in self.get_visible_children()]
#     371         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     372
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent(self, renderer)
#     241         Return with, height, xdescent, ydescent of box
#     242         """
# --> 243         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     244         return w, h, xd, yd
#     245
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent_offsets(self, renderer)
#     437
#     438         whd_list = [c.get_extent(renderer)
# --> 439                     for c in self.get_visible_children()]
#     440
#     441         if not whd_list:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in <listcomp>(.0)
#     437
#     438         whd_list = [c.get_extent(renderer)
# --> 439                     for c in self.get_visible_children()]
#     440
#     441         if not whd_list:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent(self, renderer)
#     241         Return with, height, xdescent, ydescent of box
#     242         """
# --> 243         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     244         return w, h, xd, yd
#     245
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent_offsets(self, renderer)
#     368
#     369         whd_list = [c.get_extent(renderer)
# --> 370                     for c in self.get_visible_children()]
#     371         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     372
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in <listcomp>(.0)
#     368
#     369         whd_list = [c.get_extent(renderer)
# --> 370                     for c in self.get_visible_children()]
#     371         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     372
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent(self, renderer)
#     241         Return with, height, xdescent, ydescent of box
#     242         """
# --> 243         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     244         return w, h, xd, yd
#     245
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent_offsets(self, renderer)
#     437
#     438         whd_list = [c.get_extent(renderer)
# --> 439                     for c in self.get_visible_children()]
#     440
#     441         if not whd_list:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in <listcomp>(.0)
#     437
#     438         whd_list = [c.get_extent(renderer)
# --> 439                     for c in self.get_visible_children()]
#     440
#     441         if not whd_list:
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_extent(self, renderer)
#     816             "lp", self._text._fontproperties, ismath=False)
#     817
# --> 818         bbox, info, d = self._text._get_layout(renderer)
#     819         w, h = bbox.width, bbox.height
#     820
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     212         if ismath:
#     213             ox, oy, width, height, descent, fonts, used_characters = \
# --> 214                 self.mathtext_parser.parse(s, self.dpi, prop)
#     215             return width, height, descent
#     216
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3267             self.__class__._parser = Parser()
#    3268
# -> 3269         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3270         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3271         return font_output.get_results(box)
#
# ~/.local/share/virtualenvs/python_ML-mAoi_q9c/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2511                                         err.line,
#    2512                                         " " * (err.column - 1) + "^",
# -> 2513                                         str(err)]))
#    2514         self._state_stack = None
#    2515         self._em_width_cache = {}
#
# ValueError:
# \co(x)
# ^
# Unknown symbol: \co (at char 0), (line:1, col:1)

# %% [markdown]
# # pandas

# %%
import numpy
numpy.random.seed(42)
import pandas

# 10行５列の配列をつくる
data = numpy.random.randn(10,5)
print(data)

df = pandas.DataFrame(data, columns=['A','B','C','D','E'])
df

## 先頭３行を取得する
df.head(3)

## 後ろから３行をしゅとく
df.tail(3)

## index属性はDataFrameの行インデックス
df.index
### RangeIndex(start=0, stop=10, step=1)

## カラム名の取得
df.columns
### Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

## DataFrameのデータ部分の取得
df.values
## array([[ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337],
#        [-0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004],
#        [-0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783],
#        [-0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ],
#        [ 1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272],
#        [ 0.11092259, -1.15099358,  0.37569802, -0.60063869, -0.29169375],
#        [-0.60170661,  1.85227818, -0.01349722, -1.05771093,  0.82254491],
#        [-1.22084365,  0.2088636 , -1.95967012, -1.32818605,  0.19686124],
#        [ 0.73846658,  0.17136828, -0.11564828, -0.3011037 , -1.47852199],
#        [-0.71984421, -0.46063877,  1.05712223,  0.34361829, -1.76304016]])

### describe()メソッドは統計情報　最大値　最小値　平均などを計算してくる関数
df.describe()


df['B']


# 統計操作
## mean()メソッド
df.mean()

# %matplotlib inline
df.plot()
# Out:
# [[ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337]
#  [-0.23413696  1.57921282  0.76743473 -0.46947439  0.54256004]
#  [-0.46341769 -0.46572975  0.24196227 -1.91328024 -1.72491783]
#  [-0.56228753 -1.01283112  0.31424733 -0.90802408 -1.4123037 ]
#  [ 1.46564877 -0.2257763   0.0675282  -1.42474819 -0.54438272]
#  [ 0.11092259 -1.15099358  0.37569802 -0.60063869 -0.29169375]
#  [-0.60170661  1.85227818 -0.01349722 -1.05771093  0.82254491]
#  [-1.22084365  0.2088636  -1.95967012 -1.32818605  0.19686124]
#  [ 0.73846658  0.17136828 -0.11564828 -0.3011037  -1.47852199]
#  [-0.71984421 -0.46063877  1.05712223  0.34361829 -1.76304016]]
